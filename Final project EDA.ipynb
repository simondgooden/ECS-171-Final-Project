# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("Weather-related disease prediction.csv")


# Select continuous numeric columns for outlier detection
numeric_cols = ['Age', 'Temperature (C)', 'Humidity', 'Wind Speed (km/h)']

# 1. Boxplots for each selected column
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# 2. Detect outliers using IQR method
def count_iqr_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return ((series < lower_bound) | (series > upper_bound)).sum()

# Count and print outliers for each column
print("Number of outliers (based on IQR method):")
for col in numeric_cols:
    outlier_count = count_iqr_outliers(df[col])
    print(f"{col}: {outlier_count}")
# Out:
# Number of outliers (based on IQR method):
# Age: 0
# Temperature (C): 2
# Humidity: 0
# Wind Speed (km/h): 11
